# %% [markdown]
# Load all the necessary libraries in below

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
#read a calibration image
img  = mpimg.imread('calibration_test.png')
plt.imshow(img)

# %%
# %matplotlib qt
#arrays to store the object points and image points from all the images
objpoints =[] #3d points in real world space
imgpoints = [] #2d points in image plane

#x is 8 and y is 6 for us
#prepare object points like (0,0,0),(0,1,0)...(2,0,0)....(7,5,0) etc
objp = np.zeros((6*8,3),np.float32)
objp[:,:2] = np.mgrid[0:8,0:6].T.reshape(-1,2)


#convert the image to grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# Find the chessboard corners
ret, corners = cv2.findChessboardCorners(gray, (8, 6), None)



# If found, draw corners
if ret == True:
    imgpoints.append(corners)
    objpoints.append(objp)
    
    
    # Draw and display the corners
    img_det =  cv2.drawChessboardCorners(img, (nx, ny), corners, ret)
    plt.imshow(img_det)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-fa14ec3e6595> in <module>
#      14
#      15 # Find the chessboard corners
# ---> 16 ret, corners = cv2.findChessboardCorners(gray, (8, 6), None)
#      17
#      18
#
# error: OpenCV(3.4.1) C:\Miniconda3\conda-bld\opencv-suite_1533128839831\work\modules\calib3d\src\calibinit.cpp:446: error: (-210) Only 8-bit grayscale or color images are supported in function cvFindChessboardCorners
